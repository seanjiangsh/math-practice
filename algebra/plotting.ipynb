# %% [markdown]
# # A plotting for math testing space

# %% [markdown]
# ## Utilities

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from plotting_utils import LineDict, FillDict, LimitDict # Type definitions
from plotting_utils import setup_plot

def plot_lines(title:str, lines:list[LineDict], fills:list[FillDict]=None, limits:LimitDict=None):

    plt.figure(figsize=(6, 6))
    
    for line in lines:
        x = line['x']
        y = line['y']
        line_color = line.get('color', 'blue')
        linestyle = line.get('linestyle', '-')
        label = line.get('label', None)
        plt.plot(x, y, color=line_color, linestyle=linestyle, label=label)

        # Plot points
        points = line.get('points', [])
        for point in points:
            x = point['x']
            y = point['y']
            equal = point['equal']
            point_color = line_color if equal else 'white'
            marker_edge_color = None if equal else line_color
            plt.plot(x, y, 'o', color=point_color, markersize=5, markeredgewidth=1, markeredgecolor=marker_edge_color)
        
    # Plot fills
    if fills is not None:
        for fill in fills:
            x = fill['x']
            y1 = fill['y1']
            y2 = fill['y2']
            where = fill['where']
            fill_color = fill.get('color', 'lightblue')
            plt.fill_between(x, y1, y2, where, color=fill_color, alpha=0.5)


    setup_plot(limits)
    plt.xlabel('x')
    plt.ylabel('y', rotation=0)
    plt.title(title)

    # Check if any line has a label and add legend if true
    has_label = any(map(lambda line: isinstance(line.get('label'), str), lines))
    if has_label:
        plt.legend()
    
    plt.show()

# %% [markdown]
# ## Basic slope-intercept form of line(s)

# %%
def get_slope_intercept_points(slope:float, intercept=0):
    x = np.linspace(-10, 10, 100)
    # Calculate y values based on the equation y = mx + b
    y = slope * x + intercept
    return {'x': x, 'y': y}

# %%
# y = -2/3x
points = get_slope_intercept_points(-2/3, 0)
title = r'$y = -\frac{2}{3}x$'

plot_lines(title, [points])

# %%
# y = 3x - 2
points = get_slope_intercept_points(3, -2)
title = '$y = 3x - 2$'

plot_lines(title, [points])

# %%
# y = -3/4x - 5/4
points = get_slope_intercept_points(-3/4, -5/4)
title = r'$y = -\frac{3}{4}x - \frac{5}{4}$'

plot_lines(title, [points])

# %%
# y = -5x + 6
points = get_slope_intercept_points(-5, 6)
title = '$y = -5x + 6$'

plot_lines(title, [points])

# %% [markdown]
# ## Different combinations

# %%
# y^2 = x (not a function)

# Generate x values
x = np.linspace(0, 10, 100)  # Start from 0 to avoid complex numbers

# Calculate y values based on the equation y^2 = x
y_positive = np.sqrt(x)
y_negative = -np.sqrt(x)

lines = [
    {'x': x, 'y': y_positive, 'color': 'blue'},
    {'x': x, 'y': y_negative, 'color': 'red'}
]
title = '$y^2 = x$'

plot_lines(title, lines)

# %%
# y = 1/6x
points = get_slope_intercept_points(1/6, 0)
title = '$y = \\frac{1}{6}x$'

plot_lines(title, [points])

# %%
# f(x) = 6 / x
x1 = np.linspace(-10, -0.1, 100)
x2 = np.linspace(0.1, 10, 100)

# Calculate y values based on the equation f(x) = coefficient / x
y1 = 6 / x1
y2 = 6 / x2

lines = [
    {'x': x1, 'y': y1, 'color': 'blue'},
    {'x': x2, 'y': y2, 'color': 'red'}
]
title = '$f(x) = \\frac{6}{x}$'

plot_lines(title, lines)

# %%
# f(x) = x^5 - 3x^3

x = np.linspace(-3, 3, 100)
y = (lambda x: x**5 - 3*x**3)(x)

lines = [{'x': x, 'y': y}]
title = '$f(x) = x^5 - 3x^3$'

plot_lines(title, lines)

# %%
# f(x) = 5x^2 - x^4

x = np.linspace(-3, 3, 100)
y = (lambda x: 5*x**2 - x**4)(x)

lines = [{'x': x, 'y': y}]
title = '$f(x) = 5x^2 - x^4$'

plot_lines(title, lines)

# %%
# f(x) = 5x^2 - x^3

x = np.linspace(-3, 3, 100)
y = (lambda x: 5*x**2 - x**3)(x)

lines = [{'x': x, 'y': y}]
title = '$f(x) = 5x^2 - x^3$'

plot_lines(title, lines)

# %%
# f(x) = -x^4 - 6x^2

x = np.linspace(-3, 3, 100)
y = (lambda x: -1*x**4 - 6*x**2)(x)

lines = [{'x': x, 'y': y}]
title = '$f(x) = -x^4 - 6x^2$'

plot_lines(title, lines)

# %%
# y=2/x

# Create a range of x values
x = np.linspace(-10, 10, 100)
# Avoid division by zero
x = x[x != 0]

# Compute the corresponding y values
y = (lambda x: 2 / x)(x)

lines = [{'x': x, 'y': y}]
title = '$y = \\frac{2}{x}$'

plot_lines(title, lines)

# %%
# y = 4/3x - 1
points = get_slope_intercept_points(4/3, -1)
title = '$y = \\frac{4}{3}x - 1$'

plot_lines(title, [points])

# %%
# y = 2/3x + 8/3
points = get_slope_intercept_points(2/3, 8/3)
title = '$y = \\frac{2}{3}x + \\frac{8}{3}$'

plot_lines(title, [points])

# %%
# y + 2 = −3x + 1 or y=-3x - 1
points = get_slope_intercept_points(-3, -1)
title = '$y = -3x - 1$'

plot_lines(title, [points])

# %%
# y= −2(3x+ 1) or y = -6x -2 
points = get_slope_intercept_points(-6, -2)
title = '$y = -6x - 2$'

plot_lines(title, [points])

# %%
# y = -2x - 8
points = get_slope_intercept_points(-2, -8)
title = '$y = -2x - 8$'

plot_lines(title, [points])

# %%
# f(x) = x^2 + 2
x = np.linspace(-3, 3, 100)
y = (lambda x: x**2 + 2)(x)

lines = [{'x': x, 'y': y}]
title = '$f(x) = x^2 + 2$'

plot_lines(title, lines)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # still has issues with the compound inequalities

# def plot_inequality(inequality):
#     fig, ax = plt.subplots(figsize=(10, 1))
    
#     x = np.linspace(-10, 10, 400)
    
#     # Handle compound inequalities
#     if '<=' in inequality and '>=' in inequality:
#         parts = inequality.split('<=')
#         a = float(parts[1].strip())
#         b = float(parts[0].split('>=')[1].strip())
#         condition = (x <= a) & (x >= b)
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='blue', markersize=10)
#         ax.plot(b, 0.5, 'o', color='blue', markersize=10)
#         ax.axvline(a, color='blue', linestyle='--')
#         ax.axvline(b, color='blue', linestyle='--')
#         title = f'${b} \\leq x \\leq {a}$'
#     elif '<=' in inequality and '>' in inequality:
#         parts = inequality.split('<=')
#         a = float(parts[1].strip())
#         b = float(parts[0].split('>')[1].strip())
#         condition = (x <= a) & (x > b)
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='blue', markersize=10)
#         ax.plot(b, 0.5, 'o', color='white', markersize=10, markeredgewidth=2, markeredgecolor='blue')
#         ax.axvline(a, color='blue', linestyle='--')
#         ax.axvline(b, color='blue', linestyle='--')
#         title = f'${b} < x \\leq {a}$'
#     elif '<' in inequality and '>=' in inequality:
#         parts = inequality.split('<')
#         a = float(parts[1].strip())
#         b = float(parts[0].split('>=')[1].strip())
#         condition = (x < a) & (x >= b)
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='white', markersize=10, markeredgewidth=2, markeredgecolor='blue')
#         ax.plot(b, 0.5, 'o', color='blue', markersize=10)
#         ax.axvline(a, color='blue', linestyle='--')
#         ax.axvline(b, color='blue', linestyle='--')
#         title = f'${b} \\leq x < {a}$'
#     elif '<=' in inequality:
#         parts = inequality.split('<=')
#         a = float(parts[1].strip())
#         condition = x <= a
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='blue', markersize=10)
#         ax.axvline(a, color='blue', linestyle='--')
#         title = f'$x \\leq {a}$'
#     elif '>=' in inequality:
#         parts = inequality.split('>=')
#         a = float(parts[1].strip())
#         condition = x >= a
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='blue', markersize=10)
#         ax.axvline(a, color='blue', linestyle='--')
#         title = f'$x \\geq {a}$'
#     elif '<' in inequality:
#         parts = inequality.split('<')
#         a = float(parts[1].strip())
#         condition = x < a
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='white', markersize=10, markeredgewidth=2, markeredgecolor='blue')
#         ax.axvline(a, color='blue', linestyle='--')
#         title = f'$x < {a}$'
#     elif '>' in inequality:
#         parts = inequality.split('>')
#         a = float(parts[1].strip())
#         condition = x > a
#         ax.fill_between(x, 0, 1, where=condition, color='grey', alpha=0.5, step='mid')
#         ax.plot(a, 0.5, 'o', color='white', markersize=10, markeredgewidth=2, markeredgecolor='blue')
#         ax.axvline(a, color='blue', linestyle='--')
#         title = f'$x > {a}$'
#     else:
#         raise ValueError("Inequality format not recognized")

#     ax.set_xlim([-10, 10])
#     ax.set_ylim([0, 1])
#     ax.set_yticks([])
#     ax.grid(False)
#     ax.set_title(title)
#     plt.tight_layout()
#     plt.show()

# # Example usages
# plot_inequality('x < 5')
# plot_inequality('x >= 2')
# plot_inequality('2 < x <= 5')

# %% [markdown]
# ## Inequality

# %%
# x > 2
all_range = np.linspace(-10, 10, 100)
x = np.linspace(2, 2, 100)
lines = [{'x': x, 'y': all_range, 'linestyle': '--'}]
fills = [{
    'x': all_range,
    'y1': -10, # lower boundary
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': all_range >= 2
}]
title = '$x > 2$'

plot_lines(title, lines, fills)

# %%
# x <= 5
all_range = np.linspace(-10, 10, 100)
x = np.linspace(5, 5, 100)
lines = [{'x': x, 'y': all_range}]
fills = [{
    'x': all_range,
    'y1': -10, # lower boundary
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': all_range < 5
}]
title = '$x \\leq 5$'

plot_lines(title, lines, fills)

# %%
# 2 < x <= 5
all_range = np.linspace(-10, 10, 100)
line_1 = {
    'x': np.linspace(2, 2, 100),
    'y': all_range,
    'linestyle': '--',
    'label': '$x > 2$'
}
line_2 = {
    'x': np.linspace(5, 5, 100),
    'y': all_range,
    'label': '$x \\leq 5$',
}
fill = {
    'x': all_range,
    'y1': -10, # lower boundary
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': (all_range > 2) & (all_range <= 5)
}

title = '$2 < x \\leq 5$'

plot_lines(title, [line_1, line_2], [fill])

# %%
# y >= 1/2x -3
all_range = np.linspace(-10, 10, 100)
x = all_range
y = (lambda x: 0.5 * x - 3)(x)
lines = [{'x': x, 'y': y,}]
fills = [{
    'x': all_range,
    'y1': y, # lower boundary (the line)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': y
}]
title = '$y \\geq \\frac{1}{2}x - 3$'

plot_lines(title, lines, fills)

# %%
# y > -2x + 1
all_range = np.linspace(-10, 10, 100)
x = all_range
y = (lambda x: -2 * x + 1)(x)
lines = [{'x': x, 'y': y, 'linestyle': '--',}]
fills = [{
    'x': all_range,
    'y1': y, # lower boundary (the line)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': y
}]
title = '$y > -2x + 1$'

plot_lines(title, lines, fills)

# %%
# y <= 2x + 4
all_range = np.linspace(-10, 10, 100)
x = all_range
y = (lambda x: 2 * x + 4)(x)
lines = [{'x': x, 'y': y}]
fills = [{
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': y, # upper boundary (the line)
    'where': y
}]
title = '$y \\leq 2x + 4$'

plot_lines(title, lines, fills)

# %%
# x <= 1 or x > 4
all_range = np.linspace(-10, 10, 100)
line_1 = {
    'x': np.linspace(1, 1, 100),
    'y': all_range,
    'label': '$x \\leq 1$',
}
line_2 = {
    'x': np.linspace(4, 4, 100),
    'y': all_range,
    'linestyle': '--',
    'label': '$x > 4$',
}

fill_1 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': all_range <= 1
}
fill_2 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': all_range > 4
}

lines = [line_1, line_2]
fills = [fill_1, fill_2]
title = '$x \\leq 1$ or $x > 4$'

plot_lines(title, lines, fills)

# %%
# all range
all_range = np.linspace(-10, 10, 100)
fill = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': all_range
}
title = 'All Real Numbers'

plot_lines(title, [], [fill])

# %%
# y < x, y >= -2
all_range = np.linspace(-10, 10, 100)
x = all_range
y1 = x
y2 = np.linspace(-2, -2, 100)
lines = [
    {'x': x, 'y': y1, 'linestyle': '--', 'label': '$y < x$'},
    {'x': x, 'y': y2, 'color': 'orange', 'label': '$y \\geq -2$'}
]
fill_1 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': y1, # upper boundary (the line)
    'where': y1,
}
fill_2 = {
    'x': all_range,
    'y1': y2, # lower boundary (the line)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': y2,
    'color': '#f2d583'
}
fills = [fill_1, fill_2]
title = '$y < x$, $y \\geq -2$'

plot_lines(title, lines, fills)

# %%
# y < -2x + 3, y<= 3x - 2
all_range = np.linspace(-10, 10, 100)

x1, y1 = get_slope_intercept_points(-2, 3).values()
x2, y2 = get_slope_intercept_points(3, -2).values()

line_1 = {
    'x': x1,
    'y': y1,
    'linestyle': '--',
    'label': '$y < -2x + 3$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'color': 'orange',
    'label': '$y \\leq 3x - 2$'
}

fill_1 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': y1, # upper boundary (the line)
    'where': y1
}
fill_2 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': y2, # upper boundary (the line)
    'where': y2,
    'color': '#f2d583'
}

lines = [line_1, line_2]
fills = [fill_1, fill_2]
title = '$y < -2x + 3$, $y \\leq 3x - 2$'

plot_lines(title, lines, fills)

# %%
# y = -x + 1, y = x + 1
all_range = np.linspace(-10, 10, 100)
line_1 = {
    'x': all_range,
    'y': -all_range + 1,
    'label': '$y = -x + 1$'
}
line_2 = {
    'x': all_range,
    'y': all_range + 1,
    'label': '$y = x + 1$'
}
title = '$y = -x + 1$, $y = x + 1$'

plot_lines(title, [line_1, line_2])

# %%
# y > x + 1, y <= -x + 5
x1, y1 = get_slope_intercept_points(1, 1).values()
x2, y2 = get_slope_intercept_points(-1, 5).values()
line_1 = {
    'x': x1,
    'y': y1,
    'linestyle': '--',
    'label': '$y > x + 1$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\leq -x + 5$',
    'color': 'orange'
}

fill_1 = {
    'x': all_range,
    'y1': y1, # lower boundary (the line)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': y1
}
fill_2 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': y2, # upper boundary (the line)
    'where': y2,
    'color': '#f2d583'
}

lines = [line_1, line_2]
fills = [fill_1, fill_2]
title = '$y > x + 1$, $y \\leq -x + 5$'

plot_lines(title, lines, fills)

# %%
# 4x - 2y - 4 >= 0 (y <= 2x - 2), y >= 2x - 2
x1, y1 = get_slope_intercept_points(2, -2).values()
x2, y2 = get_slope_intercept_points(2, -2).values()
line_1 = {
    'x': x1,
    'y': y1,
    'label': '$4x - 2y - 4 \\geq 0$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\geq 2x - 2$',
    'color': 'orange'
}

fill_1 = {
    'x': all_range,
    'y1': -10, # lower boundary (between -10 and 10, all y values)
    'y2': y1, # upper boundary (the line)
    'where': y1
}
fill_2 = {
    'x': all_range,
    'y1': y2, # lower boundary (the line)
    'y2': 10, # upper boundary (between -10 and 10, all y values)
    'where': y2,
    'color': '#f2d583'
}

lines = [line_1, line_2]
fills = [fill_1, fill_2]
title = '$4x - 2y - 4 \\geq 0$, $y \\geq 2x - 2$'

plot_lines(title, lines, fills)

# %%
# sqrt(x - 2)
all_range = np.linspace(2, 10, 100)
x = all_range
y = np.sqrt(x - 2)
lines = [{'x': x, 'y': y}]
title = '$y = \\sqrt{x - 2}$'

plot_lines(title, lines)

# %%
# y = 3x - 4
points = get_slope_intercept_points(3, -4)
title = '$y = 3x - 4$'

plot_lines(title, [points])

# %% [markdown]
# ## Parallel and Perpendicular Lines

# %%
# y = -5x +2, y= 1/5x - 4
x1, y1 = get_slope_intercept_points(-5, 2).values()
x2, y2 = get_slope_intercept_points(1/5, -4).values()

# notice that the y-intercept is different for the second line
# it will change the intersection point

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = -5x + 2$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = \\frac{1}{5}x - 4$',
    'color': 'orange'
}
title = 'Perpendicular Lines'

plot_lines(title, [line_1, line_2])

# %%
# y = -1/3x + 2, y = -1/3x - 2
x1, y1 = get_slope_intercept_points(-1/3, 2).values()
x2, y2 = get_slope_intercept_points(-1/3, -2).values()
line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = -\\frac{1}{3}x + 2$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = -\\frac{1}{3}x - 2$',
    'color': 'orange'
}
title = 'Parallel Lines'

plot_lines(title, [line_1, line_2])

# %%
# y = -3x + 2
# y = 1/3x + 5
x1, y1 = get_slope_intercept_points(-3, 2).values()
x2, y2 = get_slope_intercept_points(1/3, 5).values()
line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = -3x + 2$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = \\frac{1}{3}x + 5$',
    'color': 'orange'
}
title = 'Perpendicular Lines'

plot_lines(title, [line_1, line_2])

# %%
# y = 2/3x
# y = 2/3x + 3
x1, y1 = get_slope_intercept_points(2/3, 0).values()
x2, y2 = get_slope_intercept_points(2/3, 3).values()
line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = \\frac{2}{3}x$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = \\frac{2}{3}x + 3$',
    'color': 'orange'
}
title = 'Parallel Lines'

plot_lines(title, [line_1, line_2])

# %% [markdown]
# ## Parabola

# %%
# f(x) = -x^2 + 2x + 8 (parabola)
x = np.linspace(-10, 10, 100)
y = (lambda x: -x**2 + 2 * x + 8)(x)

lines = [{'x': x, 'y': y}]
title = '$f(x) = -x^2 + 2x + 8$'

plot_lines(title, lines)

# %% [markdown]
# ## Piecewise Function

# %%
# f(x) = x^2 if x<3
# f(x) = 8 if x=3
# f(x) = 2x + 4 if x>3

x1 = np.linspace(-10, 3, 100)
y1 = x1 ** 2
p1 = {'x': 3, 'y': 3**2, 'equal': False}
label1 = '$f(x) = x^2$ if $x<3$'
line_1 = {'x': x1, 'y': y1, 'label': label1, 'points': [p1]}

x2 = np.linspace(0, 0, 0)
y2 = np.linspace(0, 0, 0)
p2 = {'x': 3, 'y': 8, 'equal': True}
label2 = '$f(x) = 8$ if $x=3$'
line_2 = {'x': x2, 'y': y2, 'label': label2, 'points': [p2], 'color': 'orange'}

x3 = np.linspace(3, 10, 100)
y3 = 2 * x3 + 4
p3 = {'x': 3, 'y': 10, 'equal': False}
label3 = '$f(x) = 2x + 4$ if $x>3$'
line_3 = {'x': x3, 'y': y3, 'label': label3, 'points': [p3], 'color': 'green'}

lines = [line_1, line_2, line_3]
title = 'Piecewise Function'

limits = {'x': (-10, 10), 'y': (0, 20)}

plot_lines(title, lines, limits=limits)

# %%
# f(x) = -3 if x < -2
# f(x) = 5/4x - 1/2 if -2 < x < 2
# f(x) = 2 if x >= 2

x1 = np.linspace(-10, -2, 100)
y1 = np.linspace(-3, -3, 100)
p1 = {'x': -2, 'y': -3, 'equal': False}
label1 = '$f(x) = -3$ if $x<=2$'
line_1 = {'x': x1, 'y': y1, 'label': label1, 'points': [p1]}

x2 = np.linspace(-2, 2, 100)
y2 = (5/4) * x2 - 1/2
label2 = '$f(x) = \\frac{5}{4}x - \\frac{1}{2}$ if $-2 < x , 2$'
line_2 = {'x': x2, 'y': y2, 'label': label2, 'color': 'orange'}

x3 = np.linspace(2, 10, 100)
y3 = np.linspace(2, 2, 100)
p3 = {'x': 2, 'y': 2, 'equal': False}
label3 = '$f(x) = 2$ if $x>2$'
line_3 = {'x': x3, 'y': y3, 'label': label3, 'points':[p3], 'color': 'green'}

lines = [line_1, line_2, line_3]
title = 'Piecewise Function'

plot_lines(title, lines)

# %%
# y = (x+3)^2 if x < 0
# y = x + 9 if x >= 0

x1 = np.linspace(-10, 0, 100)
y1 = (x1 + 3)**2
x2 = np.linspace(0, 10, 100)
y2 = x2 + 9

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = (x+3)^2$ if $x < 0$',
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = x + 9$ if $x \\geq 0$',
    'color': 'orange',
}

lines = [line_1, line_2]
limits = {'x': (-10, 10), 'y': (-5, 15)}
title = 'Piecewise Function'

plot_lines(title, lines, limits=limits)

# %%
# y = -2 if x < -3
# y = 2/3x if -3 < x < 6
# y = 4 if x > 6

x1 = np.linspace(-10, -3, 100)
y1 = np.linspace(-2, -2, 100)
x2 = np.linspace(-3, 6, 100)
y2 = 2/3 * x2
x3 = np.linspace(6, 10, 100)
y3 = np.linspace(4, 4, 100)

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = -2$ if $x < -3$',
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = \\frac{2}{3}x$ if $-3 < x < 6$',
    'color': 'orange',
}
line_3 = {
    'x': x3,
    'y': y3,
    'label': '$y = 4$ if $x > 6$',
    'color': 'green',
}

lines = [line_1, line_2, line_3]
title = 'Piecewise Function'

plot_lines(title, lines)

# %%
# y = -x^2 if x < 1
# y = 1 if x = 1
# y = x + 2 if x > 1

x1 = np.linspace(-10, 1, 100)
y1 = -x1 ** 2
p1 = {'x': 1, 'y': -1, 'equal': False}

x2 = np.linspace(1, 1, 100)
y2 = np.linspace(1, 1, 100)
p2 = {'x': 1, 'y': 1, 'equal': True}

x3 = np.linspace(1, 10, 100)
y3 = x3 + 2
p3 = {'x': 1, 'y': 3, 'equal': False}

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y = -x^2$ if $x < 1$',
    'points': [p1]
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y = 1$ if $x = 1$',
    'points': [p2],
    'color': 'orange'
}
line_3 = {
    'x': x3,
    'y': y3,
    'label': '$y = x + 2$ if $x > 1$',
    'points': [p3],
    'color': 'green'
}

lines = [line_1, line_2, line_3]
title = 'Piecewise Function'

plot_lines(title, lines)

# %%
# f(x) = x^2 if x < -1
# f(x) = 1/2x - 3 if x >= -1

x1 = np.linspace(-10, -1, 100)
y1 = x1 ** 2
p1 = {'x': -1, 'y': 1, 'equal': False}

x2 = np.linspace(-1, 10, 100)
y2 = 1/2 * x2 - 3
p2 = {'x': -1, 'y': 1/2 * -1 - 3 , 'equal': True}

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$f(x) = x^2$ if $x < -1$',
    'points': [p1]
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$f(x) = \\frac{1}{2}x - 3$ if $x \\geq -1$',
    'points': [p2],
    'color': 'orange'
}

lines = [line_1, line_2]
title = 'Piecewise Function'

plot_lines(title, lines)

# %%
# f(x) = x^2 - 2 if x < 0
# f(x) = 4 if x = 0
# f(x) = -x^2 + 8 if x > 0

x1 = np.linspace(-10, 0, 100)
y1 = x1 ** 2 - 2
p1 = {'x': 0, 'y': -2, 'equal': False}

x2 = np.linspace(0, 0, 100)
y2 = np.linspace(4, 4, 100)
p2 = {'x': 0, 'y': 4, 'equal': True}

x3 = np.linspace(0, 10, 100)
y3 = -x3 ** 2 + 8
p3 = {'x': 0, 'y': 8, 'equal': False}

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$f(x) = x^2 - 2$ if $x < 0$',
    'points': [p1]
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$f(x) = 4$ if $x = 0$',
    'points': [p2],
    'color': 'orange'
}
line_3 = {
    'x': x3,
    'y': y3,
    'label': '$f(x) = -x^2 + 8$ if $x > 0$',
    'points': [p3],
    'color': 'green'
}

lines = [line_1, line_2, line_3]
title = 'Piecewise Function'

plot_lines(title, lines)

# %%
# f(x) = -x + 1 if x < -4
# f(x) = 5 if -4 < x <= 3
# f(x) = -2x + 11 if x > 3

x1 = np.linspace(-10, -4, 100)
y1 = -x1 + 1
p1 = {'x': -4, 'y': -(-4) + 1, 'equal': False}

x2 = np.linspace(-4, 3, 100)
y2 = np.linspace(5, 5, 100)
p2 = {'x': 3, 'y': 5, 'equal': True}

x3 = np.linspace(3, 10, 100)
y3 = -2 * x3 + 11

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$f(x) = -x + 1$ if $x < -4$',
    'points': [p1]
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$f(x) = 5$ if $-4 < x \\leq 3$',
    'points': [p2],
    'color': 'orange'
}
line_3 = {
    'x': x3,
    'y': y3,
    'label': '$f(x) = -2x + 11$ if $x > 3$',
    'color': 'green'
}

lines = [line_1, line_2, line_3]
title = 'Piecewise Function'

plot_lines(title, lines)

# %%
# A plane takes off and then cruises at 30,000 feet for several hours 
# before rising in elevation to 35,000 feet to avoid turbulence for the last few 
# hours. The plane then reaches its destination and lands


# taking off
x1 = np.linspace(0, 10, 100)
y1 = np.linspace(0, 30, 100)

# cruising at 30,000 feet
x2 = np.linspace(10, 20, 100)
y2 = np.linspace(30, 30, 100)

# rising to 35,000 feet
x3 = np.linspace(20, 25, 100)
y3 = np.linspace(30, 35, 100)

# cruising at 35,000 feet
x4 = np.linspace(25, 40, 100)
y4 = np.linspace(35, 35, 100)

# landing
x5 = np.linspace(40, 50, 100)
y5 = np.linspace(35, 0, 100)

line_1 = {'x': x1, 'y': y1,}
line_2 = {'x': x2, 'y': y2,}
line_3 = {'x': x3, 'y': y3,}
line_4 = {'x': x4, 'y': y4,}
line_5 = {'x': x5, 'y': y5,}

lines = [line_1, line_2, line_3, line_4, line_5]
title = 'Flight Path (x: time, y: 1000 feet)'
limits = {'x': (0, 50), 'y': (0, 50)}

plot_lines(title, lines, limits=limits)

# %%
# The temperature throughout a summer day starts at 65∘ F at 6:00 a.m.. 
# Over the next few hours the temperature rises steadily until it reaches 85∘ F at 1:00 p.m..
# At 1:15 p.m., a rainstorm begins and cools the temperature down to 75∘ F.
# The temperature then steadily decreases until it reaches 70∘ F at 9:00 p.m..

# 65 degrees at 6:00 a.m.
x1 = np.linspace(0, 6, 100)
y1 = np.linspace(0, 65, 100)

# temperature rises to 85 degrees at 1:00 p.m.
x2 = np.linspace(6, 13, 100)
y2 = np.linspace(65, 85, 100)

# rainstorm cools the temperature to 75 degrees at 1:15 p.m.
x3 = np.linspace(13, 13.25, 100)
y3 = np.linspace(85, 75, 100)

# temperature decreases to 70 degrees at 9:00 p.m.
x4 = np.linspace(13.25, 21, 100)
y4 = np.linspace(75, 70, 100)

# temperature stays at 70 degrees until midnight
x5 = np.linspace(21, 24, 100)
y5 = np.linspace(70, 70, 100)

line_1 = {'x': x1, 'y': y1,}
line_2 = {'x': x2, 'y': y2,}
line_3 = {'x': x3, 'y': y3,}
line_4 = {'x': x4, 'y': y4,}
line_5 = {'x': x5, 'y': y5,}

lines = [line_1, line_2, line_3, line_4, line_5]
title = 'Temperature Throughout the Day (x: time, y: temperature in F)'
limits = {'x': (0, 24), 'y': (0, 100)}

plot_lines(title, lines, limits=limits)

# %%
# Brett goes for a hike up a mountain.
# He starts hiking up steadily for several hours with two stops for water.
# Then Brett stops for an hour to eat lunch and rest.
# He then continues up the mountain, summits,
# and spends a little time at the top of the mountain before climbing down.

# hiking up steadily
x1 = np.linspace(0, 5, 100)
y1 = np.linspace(0, 10, 100)

# first stop for water
x2 = np.linspace(5, 8, 100)
y2 = np.linspace(10, 10, 100)

# hiking up steadily
x3 = np.linspace(8, 13, 100)
y3 = np.linspace(10, 20, 100)

# second stop for water
x4 = np.linspace(13, 15, 100)
y4 = np.linspace(20, 20, 100)

# hiking up steadily
x5 = np.linspace(15, 20, 100)
y5 = np.linspace(20, 30, 100)

# lunch break
x6 = np.linspace(20, 23, 100)
y6 = np.linspace(30, 30, 100)

# hiking up to the summit
x7 = np.linspace(23, 28, 100)
y7 = np.linspace(30, 35, 100)

# spending time at the top
x8 = np.linspace(28, 30, 100)
y8 = np.linspace(35, 35, 100)

# climbing down
x9 = np.linspace(30, 40, 100)
y9 = np.linspace(35, 0, 100)

lines = [
    {'x': x1, 'y': y1},
    {'x': x2, 'y': y2},
    {'x': x3, 'y': y3},
    {'x': x4, 'y': y4},
    {'x': x5, 'y': y5},
    {'x': x6, 'y': y6},
    {'x': x7, 'y': y7},
    {'x': x8, 'y': y8},
    {'x': x9, 'y': y9},
]
title = 'Brett\'s Hike (x: time, y: elevation)'
limits = {'x': (0, 40), 'y': (0, 40)}

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## Quadratic Inequalities (Parabola)

# %%
# x^2 - 9x + 14 <= 0
# (x - 2)(x - 7) <= 0

discriminant = (-9)**2 - 4 * 1 * 14
print(f'We have 2 real roots (2 zeros) because the discriminant is {discriminant} and it is positive')
vertex_x = -(-9) / (2 * 1)
vertex = (vertex_x, vertex_x**2 - 9 * vertex_x + 14)
print(f'The vertex of the parabola is {vertex}')
print(f'The parabola opens upwards because the coefficient of x^2 is positive')
print('So the parabola will be below the x-axis between the zeros, and the zeros are 2 and 7')
print('Therefore, the solution to the inequality is 2 <= x <= 7')

x = np.linspace(2, 7, 100)
y = (lambda x: x**2 - 9*x + 14)(x)

lines = [{'x': x, 'y': y}]
title = '$x^2 - 9x + 14 \\leq 0$'
limits = {'x': (0, 15), 'y': (-10, 5)}

plot_lines(title, lines, limits=limits)
# Out:
# We have 2 real roots (2 zeros) because the discriminant is 25 and it is positive
# The vertex of the parabola is (4.5, -6.25)
# The parabola opens upwards because the coefficient of x^2 is positive
# So the parabola will be below the x-axis between the zeros, and the zeros are 2 and 7
# Therefore, the solution to the inequality is 2 <= x <= 7

# %%
# x^2 + 2x - 3 < 0
# (x + 3)(x - 1) < 0

discriminant = 2**2 - 4*1*(-3)
print(f'We have 2 real roots because the discriminant is {discriminant} and it is positive')
vertex_x = -2 / (2 * 1)
vertex = (vertex_x, vertex_x**2 + 2 * vertex_x - 3)
print(f'The vertex of the parabola is {vertex}')
print(f'The parabola opens upwards because the coefficient of x^2 is positive')
print('So the parabola will be below the x-axis between the zeros, and the zeros are -3 and 1')
print('Therefore, the solution to the inequality is -3 < x < 1')

x = np.linspace(-3, 1, 100)
y = (lambda x: x**2 + 2*x - 3)(x)

lines = [{'x': x, 'y': y}]
title = '$x^2 + 2x - 3 < 0$'
limits = {'x': (-5, 5), 'y': (-5, 5)}

plot_lines(title, lines, limits=limits)
# Out:
# We have 2 real roots because the discriminant is 16 and it is positive
# The vertex of the parabola is (-1.0, -4.0)
# The parabola opens upwards because the coefficient of x^2 is positive
# So the parabola will be below the x-axis between the zeros, and the zeros are -3 and 1
# Therefore, the solution to the inequality is -3 < x < 1

# %%
# x^2 + 10x + 21 > 0
# (x + 3)(x + 7) > 0

discriminant = 10**2 - 4*1*21
print(f'We have 2 real roots because the discriminant is {discriminant} and it is positive')
vertex_x = -10 / (2 * 1)
vertex = (vertex_x, vertex_x**2 + 10 * vertex_x + 21)
print(f'The vertex of the parabola is {vertex}')
print(f'The parabola opens upwards because the coefficient of x^2 is positive')
print('So the parabola will be above the x-axis of the zeros, and the zeros are -3 and -7')
print('Therefore, the solution to the inequality is x < -7 and x > -3')

x1 = np.linspace(-10, -7, 100)
y1 = (lambda x: x**2 + 10*x + 21)(x1)
line_1 = {'x': x1, 'y': y1, 'label': '$x^2 + 10x + 21 > 0$'}

x2 = np.linspace(-3, 10, 100)
y2 = (lambda x: x**2 + 10*x + 21)(x2)
line_2 = {'x': x2, 'y': y2}

lines = [line_1, line_2]
title = '$x^2 + 10x + 21 > 0$'
limits = {'x': (-15, 5), 'y': (-5, 15)}

plot_lines(title, lines, limits=limits)
# Out:
# We have 2 real roots because the discriminant is 16 and it is positive
# The vertex of the parabola is (-5.0, -4.0)
# The parabola opens upwards because the coefficient of x^2 is positive
# So the parabola will be above the x-axis of the zeros, and the zeros are -3 and -7
# Therefore, the solution to the inequality is x < -7 and x > -3

# %%
# -x^2 + x + 12 >= 0
# (x - 4)(x + 3) >= 0

discriminant = 1**2 - 4*(-1)*12
print(f'We have 2 real roots (2 zeros) because the discriminant is {discriminant} and it is positive')
vertex_x = ((-1) / (2 * (-1)))
vertex = (vertex_x, -vertex_x**2 + vertex_x + 12)
print(f'The vertex of the parabola is {vertex}')
print(f'The parabola opens downwards because the coefficient of x^2 is negative')
print('So the parabola will be above the x-axis between the zeros, and the zeros are -3 and 4')
print('Therefore, the solution to the inequality is -3 <= x <= 4')

x = np.linspace(-3, 4, 100)
y = (lambda x: -x**2 + x + 12)(x)
lines = [{'x': x, 'y': y}]

title = '$-x^2 + x + 12 \\geq 0$'
limits = {'x': (-10, 10), 'y': (-5, 15)}

plot_lines(title, lines, limits=limits)
# Out:
# We have 2 real roots (2 zeros) because the discriminant is 49 and it is positive
# The vertex of the parabola is (0.5, 12.25)
# The parabola opens downwards because the coefficient of x^2 is negative
# So the parabola will be above the x-axis between the zeros, and the zeros are -3 and 4
# Therefore, the solution to the inequality is -3 <= x <= 4

# %%
# x^2 - 6x + 9 <= 0

discriminant = (-6)**2 - 4*1*9
print(f'We have 1 real root because the discriminant is {discriminant} and it is 0')
vertex_x = -(-6) / (2 * 1)
vertex = (vertex_x, vertex_x**2 - 6 * vertex_x + 9)
print(f'The vertex of the parabola is {vertex}')
print(f'The parabola opens upwards because the coefficient of x^2 is positive')
print('So the parabola will touch the x-axis at the (0,3)')
print('Therefore, the solution to the equation is x = 3')

x = np.linspace(-10, 10, 100)
y = (lambda x: x**2 - 6*x + 9)(x)

lines = [{'x': x, 'y': y, 'label': '$(x - 3)^2 \\leq 0$'}]
title = '$x^2 - 6x + 9 \\leq 0$'
limits = {'x': (-5, 10), 'y': (-5, 10)}

plot_lines(title, lines, limits=limits)
# Out:
# We have 1 real root because the discriminant is 0 and it is 0
# The vertex of the parabola is (3.0, 0.0)
# The parabola opens upwards because the coefficient of x^2 is positive
# So the parabola will touch the x-axis at the (0,3)
# Therefore, the solution to the equation is x = 3

# %%
# -x^2 + 4 > 0
# (x+2)(x-2) = 0

discriminant = 0**2 - 4*(-1)*4
print(f'We have 2 real roots because the discriminant is {discriminant} and it is positive')
vertex_x = 0 / (2 * (-1))
vertex = (vertex_x, -vertex_x**2 + 4)
print(f'The vertex of the parabola is {vertex}')
print(f'The parabola opens downwards because the coefficient of x^2 is negative')
print('So the parabola will be above the x-axis')
print('Therefore, the solution to the inequality is -2 < x < 2')

x = np.linspace(-2, 2, 100)
y = (lambda x: -x**2 + 4)(x)

lines = [{'x': x, 'y': y}]
title = '$-x^2 + 4 > 0$'

plot_lines(title, lines)
# Out:
# We have 2 real roots because the discriminant is 16 and it is positive
# The vertex of the parabola is (-0.0, 4.0)
# The parabola opens downwards because the coefficient of x^2 is negative
# So the parabola will be above the x-axis
# Therefore, the solution to the inequality is -2 < x < 2

# %% [markdown]
# ## Systems with quadratic inequalities

# %%
# y > 2x + 1
# y <= (2x + 1)(x - 3)

x1 = np.linspace(-10, 10, 100)
y1 = 2 * x1 + 1
x2 = np.linspace(-10, 10, 100)
y2 = (2 * x2 + 1) * (x2 - 3)

line_1 = {
    'x': x1,
    'y': y1,
    'linestyle': '--',
    'label': '$y > 2x + 1$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\leq (2x + 1)(x - 3)$',
    'color': 'orange'
}

# fill_1 = {
#     'x': x1,
#     'y1': y1,
#     'y2': 10,
#     'where': y1
# }
# fill_2 = {
#     'x': x2,
#     'y1': -10,
#     'y2': y2,
#     'where': y2,
#     'color': '#f2d583'
# }
fill = {
    'x': x1,
    'y1': y1,
    'y2': y2,
    'where': (y1 < y2),
    'color': '#e374b5'
}
# x, y1, y2, where=(y1 < y2)
lines = [line_1, line_2]
# fills = [fill_1, fill_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# y > 5x^2 - 6
# y <= -3x

x1 = np.linspace(-10, 10, 100)
y1 = 5 * x1**2 - 6
x2 = np.linspace(-10, 10, 100)
y2 = -3 * x2

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y > 5x^2 - 6$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\leq -3x$',
    'color': 'orange'
}

# fill_1 = {
#     'x': x1,
#     'y1': y1,
#     'y2': 10,
#     'where': y1
# }
# fill_2 = {
#     'x': x2,
#     'y1': -10,
#     'y2': y2,
#     'where': y2,
#     'color': '#f2d583'
# }
fill = {
    'x': x1,
    'y1': y1,
    'y2': y2,
    'where': (y1 < y2),
    'color': '#e374b5'
}

lines = [line_1, line_2]
# fills = [fill_1, fill_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# y >= x^2 - 2
# 5y >= x (y >= 1/5x)

x1 = np.linspace(-10, 10, 100)
y1 = x1**2 - 2
x2 = np.linspace(-10, 10, 100)
y2 = x2 / 5

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y \\geq x^2 - 2$'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\geq \\frac{1}{5}x$',
    'color': 'orange'
}

fill = {
    'x': x1,
    'y1': np.maximum(y1, y2),
    'y2': 10,
    'where': (y1 <= 10) & (y2 <= 10),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = '$y \\geq x^2 - 2, 5y \\geq x$'

plot_lines(title, lines, fills)

# %%
# x + y < -1 (y < -x - 1)
# y <= x^2 + 4x + 3

x1 = np.linspace(-10, 10, 100)
y1 = -x1 - 1
x2 = np.linspace(-10, 10, 100)
y2 = x2**2 + 4*x2 + 3

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y < -x - 1$',
    'linestyle': '--'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\leq x^2 + 4x + 3$',
    'color': 'orange'
}

fill = {
    'x': x1,
    'y1': np.minimum(y1, y2),
    'y2': -10,
    'where': (y1 >= -10) & (y2 >= -10),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = '$x + y < -1, y \\leq x^2 + 4x + 3$'

plot_lines(title, lines, fills)

# %%
# y >= 1/2x - 1
# y > -1/2x^2 + 2

x1 = np.linspace(-10, 10, 100)
y1 = 1/2 * x1 - 1
x2 = np.linspace(-10, 10, 100)
y2 = -1/2 * x2**2 + 2

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y \\geq \\frac{1}{2}x - 1$',
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y > -\\frac{1}{2}x^2 + 2$',
    'color': 'orange',
    'linestyle': '--'
}

fill = {
    'x': x1,
    'y1': np.maximum(y1, y2),
    'y2': 10,
    'where': (y1 <= 10) & (y2 <= 10),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# y < x + 3
# y > x^2 -2x + 1

x1 = np.linspace(-10, 10, 100)
y1 = x1 + 3
x2 = np.linspace(-10, 10, 100)
y2 = x2**2 - 2*x2 + 1

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y < x + 3$',
    'linestyle': '--'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y > x^2 - 2x + 1$',
    'linestyle': '--',
    'color': 'orange'
}

fill = {
    'x': x1,
    'y1': y1,
    'y2': y2,
    'where': (y1 > y2),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# y >= x^2 - 4x
# x < 2

all_range = np.linspace(-10, 10, 100)
x1 = np.linspace(-10, 10, 100)
y1 = x1**2 - 4*x1
x2 = np.linspace(2, 2, 100)
y2 = np.linspace(-10, 10, 100)

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y \\geq x^2 - 4x$',
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$x < 2$',
    'color': 'orange',
    'linestyle': '--'
}

fill = {
    'x': x1,
    'y1': y1,
    'y2': 10,
    'where': all_range < 2,
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# 4y <= x + 8 (y <= 1/4x + 2)
# x^2 + 4x + 4y > 0 (y > -1/4x^2 - x)

x1 = np.linspace(-10, 10, 100)
y1 = 1/4 * x1 + 2
x2 = np.linspace(-10, 10, 100)
y2 = -1/4 * x2**2 - x2

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y <= \\frac{1}{4}x + 2$',
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y > -\\frac{1}{4}x^2 - x$',
    'color': 'orange',
    'linestyle': '--'
}

fill = {
    'x': x1,
    'y1': y1,
    'y2': y2,
    'where': (y1 > y2),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# y >= 0
# y >= x^2 + 2x + 2

x1 = np.linspace(-10, 10, 100)
y1 = np.linspace(0, 0, 100)
x2 = np.linspace(-10, 10, 100)
y2 = x2**2 + 2*x2 + 2

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y \\geq 0$',
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\geq x^2 + 2x + 2$',
    'color': 'orange',
}

fill = {
    'x': x1,
    'y1': np.maximum(y1, y2),
    'y2': 10,
    'where': y2,
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# x - 3y < -9 (y > x/3 + 3)
# y <= (x - 2)^2

x1 = np.linspace(-10, 10, 100)
y1 = x1 / 3 + 3
x2 = np.linspace(-10, 10, 100)
y2 = (x2 - 2)**2

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y > \\frac{x}{3} + 3$',
    'linestyle': '--'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y \\leq (x - 2)^2$',
    'color': 'orange',
}

fill = {
    'x': x1,
    'y1': y1,
    'y2': y2,
    'where': (y2 > y1),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)

# %%
# y < 2x + 1
# y > 2x + 1 - x^2 (y > -x^2 + 2x + 1)

x1 = np.linspace(-10, 10, 100)
y1 = 2 * x1 + 1
x2 = np.linspace(-10, 10, 100)
y2 = -x2**2 + 2*x2 + 1

line_1 = {
    'x': x1,
    'y': y1,
    'label': '$y < 2x + 1$',
    'linestyle': '--'
}
line_2 = {
    'x': x2,
    'y': y2,
    'label': '$y > -x^2 + 2x + 1$',
    'color': 'orange',
    'linestyle': '--'
}

fill = {
    'x': x1,
    'y1': y1,
    'y2': y2,
    'where': (y1 > y2),
    'color': '#e374b5'
}

lines = [line_1, line_2]
fills = [fill]
title = 'Systems with quadratic inequalities'

plot_lines(title, lines, fills)
