# %% [markdown]
# # Trigonometry

# %% [markdown]
# ## Unit-circle Plottings

# %%
import sys
import os
import importlib

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Assuming utils/ is a sibling folder of the notebook's directory
utils_path = os.path.join(notebook_dir, '..', 'utils')
# Add utils/ to sys.path
if utils_path not in sys.path:
    sys.path.append(utils_path)

import plotting

# Reload the plotting module to reflect any changes
importlib.reload(plotting)

from plotting import plot_radian_in_unit_circle, plot_lines, get_segment_lines_by_peaks

# %%
import math
import sympy as sp
import numpy as np

# %% [markdown]
# $radian = 4\pi / 3$

# %%
title = f"Radians 4*pi/3 in Unit Circle"
plot_radian_in_unit_circle(4*math.pi/3, title)

# %% [markdown]
# ## Sine and Cosine

# %%
# y = sin(x)
x = np.linspace(-10, 10, 400)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {
    "x": x,
    "y": y1,
    "label": label_1,
    "points": point_1
}

# y = 3 * sin(x/2)
y2 = (lambda x: 3*np.sin(x/2))(x)
label_2 = "$3 \\cdot \\sin(\\frac{x}{2})$"
point_2 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi, "y": 3, "label": "$(\\pi, 3)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 3*math.pi, "y": -3, "label": "$(3\\pi, -3)$"}
]
line_2 = {
    "x": x,
    "y": y2,
    "label": label_2,
    "points": point_2,
    "color": "red"
}

title = "$y = 3 \\cdot \\sin(\\frac{x}{2})$"
lines = [line_1, line_2]
limits = {"x": (-5, 10), "y": (-5, 5)}

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x)
x = np.linspace(-10, 10, 400)
y1 = (lambda x: np.cos(x))(x)
label_1 = "$\\cos(x)$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = -5 * cos(3x)
y2 = (lambda x: -5 * np.cos(3*x))(x)
label_2 = "$-5 \\cdot \\cos(3x)$"
point_2 = [
    {"x": 0, "y": -5, "label": "$(0, -5)$"},
    {"x": math.pi/3, "y": 5, "label": "$(\\frac{\\pi}{3}, 5)$"},
    {"x": 2*math.pi/3, "y": -5, "label": "$(\\frac{2\\pi}{3}, -5)$"},
    {"x": math.pi, "y": 5, "label": "$(\\pi, 5)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$y = -5 \\cdot \\cos(3x)$"
lines = [line_1, line_2]
limits = {
    "x": (-5, 5),
    "y": (-10, 10)
}

plot_lines(title, lines, limits=limits)

# %%
# y = sin(x)
x = np.linspace(-10, 15, 400)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = 3 * sin*(x/2)
y2 = (lambda x: 3 * np.sin(x/2))(x)
label_2 = "$3 \\cdot \\sin(\\frac{x}{2})$"
point_2 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi, "y": 3, "label": "$(\\pi, 3)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 3*math.pi, "y": -3, "label": "$(3\\pi, -3)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$y = 3 \\cdot \\sin(\\frac{x}{2})$"
lines = [line_1, line_2]
limits = {
    "x": (-5, 15),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x)
x = np.linspace(-10, 15, 400)
y1 = (lambda x: np.cos(x))(x)
label_1 = "$\\cos(x)$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = 2.6 * cos(3x)
y2 = (lambda x: 2.6 * np.cos(3*x))(x)
label_2 = "$2.6 \\cdot \\cos(3x)$"
point_2 = [
    {"x": 0, "y": 2.6, "label": "$(0, 2.6)$"},
    {"x": math.pi/3, "y": -2.6, "label": "$(\\frac{\\pi}{3}, -2.6)$"},
    {"x": 2*math.pi/3, "y": 2.6, "label": "$(\\frac{2\\pi}{3}, 2.6)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$y = 2.6 \\cdot \\cos(3x)$"
lines = [line_1, line_2]
limits = {
    "x": (-5, 5),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x)
x = np.linspace(-10, 20, 400)
y1 = (lambda x: np.cos(x))(x)
label_1 = "$\\cos(x)$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = -4 * cos(x/3)
y2 = (lambda x: -4 * np.cos(x/3))(x)
label_2 = "$-4 \\cdot \\cos(\\frac{x}{3})$"
point_2 = [
    {"x": 0, "y": -4, "label": "$(0, -4)$"},
    {"x": 3*math.pi, "y": 4, "label": "$(3\\pi, 4)$"},
    {"x": 6*math.pi, "y": -4, "label": "$(6\\pi, -4)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$y = -4 \\cdot \\cos(\\frac{x}{3})$"
lines = [line_1, line_2]
limits = {
    "x": (-0, 20),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = 2 cos(x)
x = np.linspace(-10, 10, 400)
y1 = (lambda x: 2 * np.cos(x))(x)
label_1 = "$2 \\cdot \\cos(x)$"
point_1 = [
    {"x": 0, "y": 2, "label": "$(0, 2)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -2, "label": "$(\\pi, -2)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"},
    {"x": 2*math.pi, "y": 2, "label": "$(2\\pi, 2)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = sin(2x)
y2 = (lambda x: np.sin(2*x))(x)
label_2 = "$\\sin(2x)$"
point_2 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/4, "y": 1, "label": "$(\\frac{\\pi}{4}, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": 3*math.pi/4, "y": -1, "label": "$(\\frac{3\\pi}{4}, -1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 5*math.pi/4, "y": 1, "label": "$(\\frac{5\\pi}{4}, 1)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$2 \\cdot \\cos(x)$ and $\\sin(2x)$"
lines = [line_1, line_2]
limits = {
    "x": (-5, 10),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = sin(x)
x = np.linspace(-10, 10, 400)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = 5 * sin(x)
y2 = (lambda x: 5 * np.sin(x))(x)
label_2 = "$5 \\cdot \\sin(x)$"
point_2 = [
    {"x": math.pi/2, "y": 5, "label": "$(\\frac{\\pi}{2}, 5)$"},
    {"x": 3*math.pi/2, "y": -5, "label": "$(\\frac{3\\pi}{2}, -5)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 5*math.pi/2, "y": 5, "label": "$(\\frac{5\\pi}{2}, 5)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$5 \\cdot \\sin(x)$"
lines = [line_1, line_2]

plot_lines(title, lines)

# %%
# y = -4 cos(x/2)
x = np.linspace(-10, 10, 400)
y1 = (lambda x: -4 * np.cos(x/2))(x)
label_1 = "$-4 \\cdot \\cos(\\frac{x}{2})$"
point_1 = [
    {"x": 0, "y": -4, "label": "$(0, -4)$"},
    {"x": math.pi * 2, "y": 4, "label": "$(2\\pi, 4)$"},
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

# y = 3 sin(x)
y2 = (lambda x: 3 * np.sin(x))(x)
label_2 = "$3 \\cdot \\sin(x)$"
point_2 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": 3, "label": "$(\\frac{\\pi}{2}, 3)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -3, "label": "$(\\frac{3\\pi}{2}, -3)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

title = "$-4 \\cdot \\cos(\\frac{x}{2})$ and $3 \\cdot \\sin(x)$"
lines = [line_1, line_2]
limits = {
    "x": (-5, 10),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## Cosecant and Secant

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Define x values
x = np.linspace(-10, 10, 800)
y2 = 1 / np.sin(2 * x) + 1  # Compute y = 1 + csc(2x)

# Find local minima (valleys) and maxima (peaks)
peaks, _ = find_peaks(y2, height=0)  # Find peaks (top of U-shape)
valleys, _ = find_peaks(-y2, height=0)  # Find valleys (bottom of U-shape)

jumps = np.where(np.abs(np.diff(y2)) > 10)[0]  # Detect large jumps

print("Peaks:", peaks, len(peaks))
print("jumps:", jumps, len(jumps))

# Combine peak and valley indices as segment boundaries
segment_boundaries = np.sort(np.concatenate((peaks, valleys)))

# Split data at these boundaries
x_segments = np.split(x, segment_boundaries)
y_segments = np.split(y2, segment_boundaries)

# Plot the segmented curve
plt.figure(figsize=(8, 6))
for x_seg, y_seg in zip(x_segments, y_segments):
    plt.plot(x_seg, y_seg, 'r')  # Plot only continuous segments

# Formatting
plt.ylim(-10, 10)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--')
plt.legend([r"$y = 1 + \csc(2x)$"])
plt.show()
# Out:
# Peaks: [ 23  85 149 211 274 336 400 462 526 587 651 713 777] 13
# jumps: [ 21  22  23  84  85  86 147 148 149 210 211 212 272 273 274 335 336 337
#  398 399 400 461 462 463 524 525 526 586 587 588 649 650 651 712 713 714
#  775 776 777] 39

# %%
# y = sin(2x) + 1
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(2*x) + 1)(x)
label_1 = "$\\sin(2x) + 1$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/4, "y": 2, "label": "$(\\frac{\\pi}{4}, 2)$"},
    {"x": 3*math.pi/4, "y": 0, "label": "$(\\frac{3\\pi}{4}, 0)$"},
    {"x": 5*math.pi/4, "y": 2, "label": "$(\\frac{5\\pi}{4}, 2)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = csc(2x) + 1
y2 = (lambda x: 1/np.sin(2*x) + 1)(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$\\csc(2x) + 1$"

title = "$\\sin(2x) + 1$ and $\\csc(2x) + 1$"
limits = {
    "x": (-5, 5),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = 2cos(x) - 2
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 2*np.cos(x) - 2)(x)
label_1 = "$2\\cos(x) - 2$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": -2, "label": "$(\\frac{\\pi}{2}, -2)$"},
    {"x": math.pi, "y": -4, "label": "$(\\pi, -4)$"},
    {"x": 3*math.pi/2, "y": -2, "label": "$(\\frac{3\\pi}{2}, -2)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 2sec(x) - 2
y2 = (lambda x: 2/np.cos(x) - 2)(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$2\\sec(x) - 2$"

title = "$2\\cos(x) - 2$ and $2\\sec(x) - 2$"
limits = {
    "x": (-5, 5),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = sin(x/2)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(x/2))(x)
label_1 = "$\\sin(\\frac{x}{2})$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi, "y": 1, "label": "$(\\pi, 1)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 3*math.pi, "y": -1, "label": "$(3\\pi, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = csc(x/2)
y2 = (lambda x: 1/np.sin(x/2))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$\\csc(\\frac{x}{2})$"

title = "$\\sin(\\frac{x}{2})$ and $\\csc(\\frac{x}{2})$"

plot_lines(title, lines)

# %%
# y = -cos(2x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: -np.cos(2*x))(x)
label_1 = "$-\\cos(2x)$"
point_1 = [
    {"x": 0, "y": -1, "label": "$(0, -1)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 1, "label": "$(\\frac{3\\pi}{2}, 1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = -sec(2x)
y2 = (lambda x: -1/np.cos(2*x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$-\\sec(2x)$"

title = "$-\\cos(2x)$ and $-\\sec(2x)$"
limits = {
    "x": (-5, 5),
    "y": (-5, 5)
}

plot_lines(title, lines, limits=limits)

# %%
# y = 5sin(2x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 5*np.sin(2*x))(x)
label_1 = "$5\\sin(2x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/4, "y": 5, "label": "$(\\frac{\\pi}{4}, 5)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": 3*math.pi/4, "y": -5, "label": "$(\\frac{3\\pi}{4}, -5)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 5csc(2x)
y2 = (lambda x: 5/np.sin(2*x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$5\\csc(2x)$"

title = "$5\\sin(2x)$ and $5\\csc(2x)$"
limits = {
    "x": (-5, 5),
    "y": (-10, 10)
}

plot_lines(title, lines, limits=limits)

# %%
# y = 1/4 cos(x/2)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 1/4*np.cos(x/2))(x)
label_1 = "$\\frac{1}{4}\\cos(\\frac{x}{2})$"
point_1 = [
    {"x": 0, "y": 0.25, "label": "$(0, \\frac{1}{4})$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 2*math.pi, "y": -0.25, "label": "$(2\\pi, -\\frac{1}{4})$"},
    {"x": 3*math.pi, "y": 0, "label": "$(3\\pi, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 1/4 sec(x/2)
y2 = (lambda x: 1/4/np.cos(x/2))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$\\frac{1}{4}\\sec(\\frac{x}{2})$"

title = "$\\frac{1}{4}\\cos(\\frac{x}{2})$ and $\\frac{1}{4}\\sec(\\frac{x}{2})$"
limits = { "x": (-10, 10), "y": (-5, 5) }

plot_lines(title, lines)

# %%
# y = 1/2 sin(-x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 1/2*np.sin(-x))(x)
label_1 = "$\\frac{1}{2}\\sin(-x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": -0.5, "label": "$(\\frac{\\pi}{2}, -\\frac{1}{2})$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": 0.5, "label": "$(\\frac{3\\pi}{2}, \\frac{1}{2})$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 1/2 csc(-x)
y2 = (lambda x: 1/2/np.sin(-x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$\\frac{1}{2}\\csc(-x)$"

title = "$\\frac{1}{2}\\sin(-x)$ and $\\frac{1}{2}\\csc(-x)$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = -2 cos(x/4)
x = np.linspace(-20, 20, 800)
y1 = (lambda x: -2*np.cos(x/4))(x)
label_1 = "$-2\\cos(\\frac{x}{4})$"
point_1 = [
    {"x": 0, "y": -2, "label": "$(0, -2)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 4*math.pi, "y": 2, "label": "$(4\\pi, 2)$"},
    {"x": 6*math.pi, "y": 0, "label": "$(6\\pi, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = -2 sec(x/4)
y2 = (lambda x: -2/np.cos(x/4))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$-2\\sec(\\frac{x}{4})$"

title = "$-2\\cos(\\frac{x}{4})$ and $-2\\sec(\\frac{x}{4})$"
limits = { 
  "x": (-20, 20),
  "y": (-10, 10)
}

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## Tangent and Cotangent

# %%
# y = sin(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = cos(x)
y2 = (lambda x: np.cos(x))(x)
label_2 = "$\\cos(x)$"
point_2 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

# y = tan(x)
y3 = (lambda x: np.tan(x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y3):
    seg["color"] = "green"
    lines.append(seg)

# Add the label and color for tan(x)
lines[2]["label"] = "$\\tan(x)$"
lines[2]["color"] = "green"

# y = cot(x)
y4 = (lambda x: 1/np.tan(x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y4):
    seg["color"] = "purple"
    lines.append(seg)

# Add the label and color for cot(x)
lines[3]["label"] = "$\\cot(x)$"
lines[3]["color"] = "purple"

title = "$\\sin(x)$, $\\cos(x)$, $\\tan(x)$ and $\\cot(x)$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = -2 sin(2x) + 1
x = np.linspace(-10, 10, 800)
y1 = (lambda x: -2*np.sin(2*x) + 1)(x)
label_1 = "$-2\\sin(2x) + 1$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/4, "y": -1, "label": "$(\\frac{\\pi}{4}, -1)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": 3*math.pi/4, "y": 3, "label": "$(\\frac{3\\pi}{4}, 3)$"},
    {"x": math.pi, "y": 1, "label": "$(\\pi, 1)$"},
    {"x": 5*math.pi/4, "y": -1, "label": "$(\\frac{5\\pi}{4}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = -2 tan(2x) + 1
y2 = (lambda x: -2*np.tan(2*x) + 1)(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)
  
# Add the label for 1st segment
lines[1]["label"] = "$-2\\tan(2x) + 1$"

title = "$-2\\sin(2x) + 1$ and $-2\\tan(2x) + 1$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x) - 2
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.cos(x) - 2)(x)
label_1 = "$\\cos(x) - 2$"
point_1 = [
    {"x": 0, "y": -1, "label": "$(0, -1)$"},
    {"x": math.pi/2, "y": -2, "label": "$(\\frac{\\pi}{2}, -2)$"},
    {"x": math.pi, "y": -3, "label": "$(\\pi, -3)$"},
    {"x": 3*math.pi/2, "y": -2, "label": "$(\\frac{3\\pi}{2}, -2)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = cot(x) - 2
y2 = (lambda x: 1/np.tan(x) - 2)(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$\\cot(x) - 2$"

title = "$\\cos(x) - 2$ and $\\cot(x) - 2$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = -3 sin(2x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: -3*np.sin(2*x))(x)
label_1 = "$-3\\sin(2x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/4, "y": -3, "label": "$(\\frac{\\pi}{4}, -3)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": 3*math.pi/4, "y": 3, "label": "$(\\frac{3\\pi}{4}, 3)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 5*math.pi/4, "y": -3, "label": "$(\\frac{5\\pi}{4}, -3)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = -3 tan(2x)
y2 = (lambda x: -3*np.tan(2*x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$-3\\tan(2x)$"

title = "$-3\\sin(2x)$ and $-3\\tan(2x)$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = 2 cos(-1/2x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 2*np.cos(-1/2*x))(x)
label_1 = "$2\\cos(-\\frac{1}{2}x)$"
point_1 = [
    {"x": 0, "y": 2, "label": "$(0, 2)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 2*math.pi, "y": -2, "label": "$(2\\pi, -2)$"},
    {"x": 3*math.pi, "y": 0, "label": "$(3\\pi, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 2 cot(-1/2x)
y2 = (lambda x: 2/np.tan(-1/2*x))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y2):
    seg["color"] = "red"
    lines.append(seg)

# Add the label for 1st segment
lines[1]["label"] = "$2\\cot(-\\frac{1}{2}x)$"

title = "$2\\cos(-\\frac{1}{2}x)$ and $2\\cot(-\\frac{1}{2}x)$"
limits = { "x": (-10, 10), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y= 4 sin(x/2)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 4*np.sin(x/2))(x)
label_1 = "$4\\sin(\\frac{x}{2})$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi, "y": 4, "label": "$(\\pi, 4)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 3*math.pi, "y": -4, "label": "$(3\\pi, -4)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y= 4 cos(x/2)
y2 = (lambda x: 4*np.cos(x/2))(x)
label_2 = "$4\\cos(\\frac{x}{2})$"
point_2 = [
    {"x": 0, "y": 4, "label": "$(0, 4)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 2*math.pi, "y": -4, "label": "$(2\\pi, -4)$"},
    {"x": 3*math.pi, "y": 0, "label": "$(3\\pi, 0)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

# y= 4 tan(x/2)
y3 = (lambda x: 4*np.tan(x/2))(x)

# Find peaks and segment lines
for seg in get_segment_lines_by_peaks(x, y3):
    seg["color"] = "green"
    lines.append(seg)

# Add the label for 1st segment
lines[2]["label"] = "$4\\tan(\\frac{x}{2})$"

title = "$4\\sin(\\frac{x}{2})$, $4\\cos(\\frac{x}{2})$ and $4\\tan(\\frac{x}{2})$"

plot_lines(title, lines)

# %% [markdown]
# ## Horizontal and vertical shifts

# %%
# y = sin(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = sin(x-pi)
y2 = (lambda x: np.sin(x-math.pi))(x)
label_2 = "$\\sin(x-\\pi)$"
point_2 = [
    {"x": math.pi/2, "y": -1, "label": "$(\\frac{\\pi}{2}, -1)$"},
    {"x": 3*math.pi/2, "y": 1, "label": "$(\\frac{3\\pi}{2}, 1)$"},  
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\sin(x)$ and $\\sin(x-\\pi)$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = 3 cos(x+pi/4) - 7
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 3*np.cos(x+math.pi/4) - 7)(x)
label_1 = "$3\\cos(x+\\frac{\\pi}{4}) - 7$"
point_1 = [
    {"x": 0-math.pi/4, "y": -4, "label": "$(0-\\frac{\\pi}{4}, -4)$"},
    {"x": math.pi-math.pi/4, "y": -10, "label": "$(\\pi-\\frac{\\pi}{4}, -10)$"},
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

title = "$3\\cos(x+\\frac{\\pi}{4}) - 7$"
limits = { "x": (-5, 5), "y": (-10, 0) }

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.cos(x))(x)
label_1 = "$\\cos(x)$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = cos(x) - 5
y2 = (lambda x: np.cos(x) - 5)(x)
label_2 = "$\\cos(x) - 5$"
point_2 = [
    {"x": 0, "y": -4, "label": "$(0, -4)$"},
    {"x": math.pi/2, "y": -5, "label": "$(\\frac{\\pi}{2}, -5)$"},
    {"x": math.pi, "y": -6, "label": "$(\\pi, -6)$"},
    {"x": 3*math.pi/2, "y": -5, "label": "$(\\frac{3\\pi}{2}, -5)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\cos(x)$ and $\\cos(x) - 5$"
limits = { "x": (-5, 5), "y": (-10, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = -sin(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: -np.sin(x))(x)
label_1 = "$-\\sin(x)$"
point_1 = [
    {"x": -math.pi/2, "y": 1, "label": "$(-\\frac{\\pi}{2}, 1)$"},
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi/2, "y": -1, "label": "$(\\frac{\\pi}{2}, -1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": 1, "label": "$(\\frac{3\\pi}{2}, 1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1}

lines = [line_1]

# y = -sin(x - pi/6)
y2 = (lambda x: -np.sin(x-math.pi/6))(x)
label_2 = "$-\\sin(x-\\frac{\\pi}{6})$"
point_2 = [
    {"x": -math.pi/3, "y": 1, "label": "$(-\\frac{\\pi}{3}, 1)$"},
    {"x": math.pi/6, "y": 0, "label": "$(\\frac{\\pi}{6}, 0)$"},
    {"x": 2*math.pi/3, "y": -1, "label": "$(\\frac{2\\pi}{3}, -1)$"},
    {"x": 7*math.pi/6, "y": 0, "label": "$(\\frac{7\\pi}{6}, 0)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$-\\sin(x)$ and $-\\sin(x-\\frac{\\pi}{6})$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = sin(x-pi)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(x-math.pi))(x)
label_1 = "$\\sin(x-\\pi)$"
point_1 = [
    {"x": 0, "y": 0, "label": "$(0, 0)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": 1, "label": "$(\\frac{3\\pi}{2}, 1)$"},
    {"x": 2*math.pi, "y": 0, "label": "$(2\\pi, 0)$"},
    {"x": 5*math.pi/2, "y": -1, "label": "$(\\frac{5\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = sin(x-pi/2)
y2 = (lambda x: np.sin(x-math.pi/2))(x)
label_2 = "$\\sin(x-\\frac{\\pi}{2})$"
point_2 = [
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": 1, "label": "$(\\pi, 1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"},
    {"x": 2*math.pi, "y": -1, "label": "$(2\\pi, -1)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\sin(x-\\pi)$ and $\\sin(x-\\frac{\\pi}{2})$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## (All) Transformations

# %%
# y = cos(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.cos(x))(x)
label_1 = "$\\cos(x)$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi/2, "y": 0, "label": "$(\\frac{\\pi}{2}, 0)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 3*math.pi/2, "y": 0, "label": "$(\\frac{3\\pi}{2}, 0)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = cos(3x/2)-4 (a=1, b=3/2, c=0, d=-4)
y2 = (lambda x: np.cos(3*x/2)-4)(x)
label_2 = "$\\cos(\\frac{3x}{2})-4$"
point_2 = [
    {"x": 0, "y": -3, "label": "$(0, -3)$"},
    {"x": 2*math.pi/3, "y": -5, "label": "$(\\frac{2\\pi}{3}, -5)$"},
    {"x": 4*math.pi/3, "y": -3, "label": "$(\\frac{4\\pi}{3}, -3)$"},
    {"x": 2*math.pi, "y": -4, "label": "$(2\\pi, -4)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\cos(x)$ and $\\cos(\\frac{3x}{2})-4$"
limits = { "x": (-5, 5), "y": (-10, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = sin(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 1.7sin(2(x-pi/6)) (a=1.7, b=2, c=pi/6, d=0)
y2 = (lambda x: 1.7*np.sin(2*(x-math.pi/6)))(x)
label_2 = "$1.7\\sin(2(x-\\frac{\\pi}{6}))$"
point_2 = [
    {"x": -math.pi/12, "y": -1.7, "label": "$(-\\frac{\\pi}{12}, -1.7)$"},
    {"x": math.pi/6, "y": 0, "label": "$(\\frac{\\pi}{6}, 0)$"},
    {"x": 5*math.pi/12, "y": 1.7, "label": "$(\\frac{5\\pi}{12}, 1.7)$"},
    {"x": 2* math.pi/3, "y": 0, "label": "$(2\\frac{\\pi}{3}, 0)$"},
    {"x": 11*math.pi/12, "y": -1.7, "label": "$(\\frac{11\\pi}{12}, -1.7)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\sin(x)$ and $1.7\\sin(2(x-\\frac{\\pi}{6}))$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.cos(x))(x)
label_1 = "$\\cos(x)$"
point_1 = [
    {"x": 0, "y": 1, "label": "$(0, 1)$"},
    {"x": math.pi, "y": -1, "label": "$(\\pi, -1)$"},
    {"x": 2*math.pi, "y": 1, "label": "$(2\\pi, 1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = -1.5 * cos(3/4 * (x + pi/3)) + 2  # Parameters: a=-1.5, b=3/4, c=pi/3, d=2
y2 = (lambda x: -1.5 * np.cos(3/4 * (x + math.pi/3)) + 2)(x)
label_2 = "$-1.5\\cos(\\frac{3}{4}(x+\\frac{\\pi}{3})) + 2$"
point_2 = [
    {"x": -math.pi/3, "y": 0.5, "label": "$(-\\frac{\\pi}{3}, 0.5)$"},
    {"x": math.pi/3, "y": 2, "label": "$(\\frac{2\\pi}{3}, 2)$"},
    {"x": math.pi, "y": 3.5, "label": "$(\\pi, 3.5)$"},
    {"x": 7*math.pi/3, "y": 0.5, "label": "$(\\frac{7\\pi}{3}, 0.5)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\cos(x)$ and $-1.5\\cos(\\frac{3}{4}(x+\\frac{\\pi}{3})) + 2$"
limits = { "x": (-10, 10), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = sin(x)
x = np.linspace(-10, 10, 800)
y1 = (lambda x: np.sin(x))(x)
label_1 = "$\\sin(x)$"
point_1 = [
    {"x": math.pi/2, "y": 1, "label": "$(\\frac{\\pi}{2}, 1)$"},
    {"x": math.pi, "y": 0, "label": "$(\\pi, 0)$"},
    {"x": 3*math.pi/2, "y": -1, "label": "$(\\frac{3\\pi}{2}, -1)$"}
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

# y = 2 sin(-2(x-pi/3)) parameters: a=2, b=-2, c=pi/3, d=0
y2 = (lambda x: 2*np.sin(-2*(x-math.pi/3)))(x)
label_2 = "$2\\sin(-2(x-\\frac{\\pi}{3}))$"
point_2 = [
    {"x": -math.pi/6, "y": 0, "label": "$(-\\frac{\\pi}{6}, 0)$"},
    {"x": math.pi/12, "y": 2, "label": "$(\\frac{\\pi}{12}, 2)$"},
    {"x": math.pi/3, "y": 0, "label": "$(\\frac{\\pi}{3}, 0)$"},
    {"x": 7*math.pi/12, "y": -2, "label": "$(\\frac{7\\pi}{12}, -2)$"}
]
line_2 = {"x": x, "y": y2, "label": label_2, "points": point_2, "color": "red"}

lines.append(line_2)

title = "$\\sin(x)$ and $2\\sin(-2(x-\\frac{\\pi}{3}))$"
limits = { "x": (-5, 5), "y": (-5, 5) }

plot_lines(title, lines, limits=limits)

# %%
# y = 5cos[2(x-pi/6)]
x = np.linspace(-10, 10, 800)
y1 = (lambda x: 5*np.cos(2*(x-math.pi/6)))(x)
label_1 = "$5\\cos[2(x-\\frac{\\pi}{6})]$"
point_1 = [
    {"x": 5*math.pi/12, "y": 0, "label": "$(\\frac{5\\pi}{12}, -5)$"},
    {"x": 11*math.pi/12, "y": 0, "label": "$(\\frac{11\\pi}{12}, 0)$"},
    {"x": 17*math.pi/12, "y": 0, "label": "$(\\frac{17\\pi}{12}, 5)$"},
    {"x": 23*math.pi/12, "y": 0, "label": "$(\\frac{23\\pi}{12}, 0)$"}    
]
line_1 = {"x": x, "y": y1, "label": label_1, "points": point_1}

lines = [line_1]

title = "$5\\cos[2(x-\\frac{\\pi}{6})]$"
limits = { "x": (0, 10), "y": (-10, 10) }

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## Graphing combinations

# %%
# y = cos(3x) + sin(x-pi)
x = np.linspace(-10, 10, 800)
y = (lambda x: np.cos(3 * x) + np.sin(x - math.pi))(x)
label = "$y=\\cos(3x)+\\sin(x-\\pi)$"

line = {"x": x, "y": y, "label": label}

lines = [line]

title = label
limits = {"x": (-5, 5), "y": (-5, 5)}

plot_lines(title, lines, limits=limits)

# %%
# y = (sin(2x)) * (2cos(x)+1)
x = np.linspace(-10, 10, 800)
y = (lambda x: (np.sin(2 * x)) * (2 * np.cos(x) + 1))(x)
label = "$y=(\\sin(2x)) * (2\\cos(x)+1)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-5, 5), "y": (-5, 5)}

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x+pi/4) / sin(3x-pi/2)
x = np.linspace(-10, 10, 800)
y = (lambda x: np.cos(x + math.pi / 4) / np.sin(3 * x - math.pi / 2))(x)
label = "$\\frac{\\cos(x+\\pi/4)}{\\sin(3x-\\pi/2)}$"

# Find peaks and segment lines
lines = []
for seg in get_segment_lines_by_peaks(x, y):
    lines.append(seg)

title = "$\\frac{\\cos(x+\\pi/4)}{\\sin(3x-\\pi/2)}$"
limits = {"x": (-5, 5), "y": (-2, 2)}

plot_lines(title, lines, limits=limits)

# %%
# y = 2cos(3x) + sin(2x)
x = np.linspace(-10, 10, 800)
y = (lambda x: 2 * np.cos(3 * x) + np.sin(2 * x))(x)
label = "$y=2\\cos(3x)+\\sin(2x)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-5, 5), "y": (-5, 5)}

plot_lines(title, lines, limits=limits)

# %%
# y = cos(x-pi/2) - 5sin(4x+3pi/2)
x = np.linspace(-10, 10, 800)
y = (lambda x: np.cos(x - math.pi / 2) - 5 * np.sin(4 * x + 3 * math.pi / 2))(x)
label = "$\\cos(x-\\frac{\\pi}{2}) - 5\\sin(4x+\\frac{3\\pi}{2})$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-5, 5), "y": (-10, 10)}

plot_lines(title, lines, limits=limits)

# %%
# y = 5sin(x/4+pi) - [cos(x/3+pi)-1]
x = np.linspace(-40, 40, 800)
y = (lambda x: 5 * np.sin(x / 4 + math.pi) - (np.cos(x / 3 + math.pi) - 1))(x)
label = "$5\\sin(\\frac{x}{4}+\\pi) - [\\cos(\\frac{x}{3}+\\pi)-1]$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-40, 40), "y": (-10, 10)}

plot_lines(title, lines, limits=limits)

# %%
# y = cos(2x) + 2sin(3x-pi/2)
x = np.linspace(-10, 10, 800)
y = (lambda x: np.cos(2 * x) + 2 * np.sin(3 * x - math.pi / 2))(x)
label = "$\\cos(2x) + 2\\sin(3x-\\frac{x}{2})$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-5, 5), "y": (-5, 5)}

plot_lines(title, lines, limits=limits)

# %%
# y = (2cos(3x-2pi)) * (sin(x)+2)
x = np.linspace(-10, 10, 800)
y = (lambda x: (2 * np.cos(3 * x - 2 * math.pi)) * (np.sin(x) + 2))(x)
label = "$(2\\cos(3x-2\\pi)) \\cdot (\\sin(x)+1)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label

plot_lines(title, lines)

# %%
# y = (cos(3x+3pi/4)) / (3sin(x-pi/2))
x = np.linspace(-10, 10, 800)
y = (lambda x: (np.cos(3 * x + 3 * math.pi / 4)) / (3 * np.sin(x - math.pi / 2)))(x)

# Find peaks and segment lines
lines = []
for seg in get_segment_lines_by_peaks(x, y):
    lines.append(seg)

title = "$\\frac{\\cos(3x+\\frac{3\\pi}{4})}{3\\sin(x-\\frac{\\pi}{2})}$"
limits = {"x": (-5, 5), "y": (-5, 5)}

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## Inverse trig functions

# %%
# y = arcsin(x)
x = np.linspace(-1, 1, 800)
y = (lambda x: np.arcsin(x))(x)
label = "$y=Arcsin(x)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-2, 2), "y": (-2, 2)}

plot_lines(title, lines, limits=limits)

# %%
# y = arccos(x)
x = np.linspace(-1, 1, 800)
y = (lambda x: np.arccos(x))(x)
label = "$y=Arccos(x)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-2, 2), "y": (-1, 4)}

plot_lines(title, lines, limits=limits)

# %%
# y = arctan(x)
x = np.linspace(-20, 20, 800)
y = (lambda x: np.arctan(x))(x)
label = "$y=Arctan(x)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-20, 20), "y": (-2, 2)}

plot_lines(title, lines, limits=limits)

# %%
# y = arccsc(x)
x = np.linspace(-20, 20, 800)
valid_mask = (x != 0) & (np.abs(1/x) <= 1)
y_full = np.full_like(x, np.nan)
y_full[valid_mask] = np.arcsin(1/x[valid_mask])

label = "$y=Arccsc(x)$"
line = {"x": x, "y": y_full, "label": label}
lines = [line]

title = label
limits = {"x": (-20, 20), "y": (-2, 2)}

plot_lines(title, lines, limits=limits)

# %%
# y = arcsec(x)
x = np.linspace(-20, 20, 800)
valid_mask = (x != 0) & (np.abs(1/x) <= 1)
y_full = np.full_like(x, np.nan)
y_full[valid_mask] = np.arccos(1/x[valid_mask])

label = "$y=Arcsec(x)$"
line = {"x": x, "y": y_full, "label": label}
lines = [line]

title = label
limits = {"x": (-20, 20), "y": (-1, 4)}

plot_lines(title, lines, limits=limits)

# %%
# y = arccot(x)
x = np.linspace(-20, 20, 800)

# We need to currect the range to (0, pi) instead of (-pi/2, pi/2)
# y = (lambda x: np.arctan(1/x))(x)
y = (lambda x: np.pi / 2 - np.arctan(x))(x)

label = "$y=Arccot(x)$"
line = {"x": x, "y": y, "label": label}
lines = [line]

title = label
limits = {"x": (-20, 20), "y": (-1, 4)}

plot_lines(title, lines, limits=limits)
