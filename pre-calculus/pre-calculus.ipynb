# %% [markdown]
# # Graphing Polar Equations

# %%
import math
import sympy as sp
import numpy as np

# %%
import sys
import os
import importlib

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Assuming utils/ is a sibling folder of the notebook's directory
utils_path = os.path.join(notebook_dir, '..', 'utils')
# Add utils/ to sys.path
if utils_path not in sys.path:
    sys.path.append(utils_path)

import preCalculus
import plotting

# Reload the plotting module to reflect any changes
importlib.reload(preCalculus)
importlib.reload(plotting)

from preCalculus import rectangular_to_polar, polar_to_rectangular, get_coterminal_polar_point, find_equivalent_polar_points

from plotting import plot_lines, plot_polar_equation, get_segment_lines_by_peaks

# %%
# r = 2.5 cos(3θ)
title = "$r = 2.5cos(3\\theta)$"
equation = lambda theta: 2.5 * np.cos(3 * theta)
theta_range = (0, 2 * np.pi)
limits = (0, 3)

# Create the polar plot
plot_polar_equation(title, equation, theta_range=theta_range, limits=limits)
# Out:
# Found 6 vertices:
# Vertex 1: θ = 0, r = 2.5
# Vertex 2: θ = π/3, r = -2.5
# Vertex 3: θ = 2π/3, r = 2.5
# Vertex 4: θ = π, r = -2.5
# Vertex 5: θ = 4π/3, r = 2.5
# Vertex 6: θ = 5π/3, r = -2.5

# %%
# r = 1 - 2cos(θ)
title = "$r = 1 - 2cos(\\theta)$"
equation = lambda theta: 1 - 2 * np.cos(theta)
limits = (-1, 3.5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = -1.0
# Vertex 2: θ = π, r = 3.0

# %%
# r = 1.8 - 1.8 sin(θ)
title = "$r = 1.8 - 1.8sin(\\theta)$"
equation = lambda theta: 1.8 - 1.8 * np.sin(theta)
limits = (0, 4)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = 0.0
# Vertex 2: θ = 3π/2, r = 3.6

# %%
# r = 3 * sin(θ) - 3
title = "$r = 3sin(\\theta) - 3$"
equation = lambda theta: 3 * np.sin(theta) - 3
limits = (-6, 1)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = -0.0
# Vertex 2: θ = 3π/2, r = -6.0

# %%
# r= 4 * cos(θ)
title = "$r = 4cos(\\theta)$"
equation = lambda theta: 4 * np.cos(theta)
limits = (0, 5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = 4.0
# Vertex 2: θ = π, r = -4.0

# %%
# r= 6 * sin(θ) - 2 * cos(θ)
title = "$r = 6sin(\\theta) - 2cos(\\theta)$"
equation = lambda theta: 6 * np.sin(theta) - 2 * np.cos(theta)
limits = (0, 7)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0.60π, r = 6.32
# Vertex 2: θ = 1.60π, r = -6.32

# %%
# r^2 * sin(2θ) = 1
# we can express the equation as y = 1 / (2 * x)
title = "$r^2sin(2\\theta) = 1$"
x = np.linspace(-5, 5, 1000)
y = (lambda x: 1 / (2 * x))(x)

# Find peaks and segment lines
lines = []
for seg in get_segment_lines_by_peaks(x, y):
    lines.append(seg)
    
limits = {"x": (-3, 3), "y": (-3, 3)}

plot_lines(title, lines, limits=limits)

# %%
# rcos(θ)  - tan(θ) + 2 = 0
# we can express the equation as y = x(x+2)
title = "$rcos(\\theta) - tan(\\theta) + 2 = 0$"
x = np.linspace(-5, 5, 1000)
y = (lambda x: x * (x + 2))(x)
lines = [{'x': x, 'y': y}]
limits = {"x": (-5, 3), "y": (-2, 6)}

plot_lines(title, lines, limits=limits)

# %%
# r^2 = sin(θ) / cos(θ)
# we can express the equation as y = x^3
title = "$r^2 = \\frac{sin(\\theta)}{cos(\\theta)}$"
x = np.linspace(-5, 5, 1000)
y = (lambda x: x**3)(x)
lines = [{'x': x, 'y': y}]
limits = {"x": (-2, 2), "y": (-2, 2)}

plot_lines(title, lines, limits=limits)

# %% [markdown]
# ## Graphing Circles

# %%
# r = -7 * cos(θ)
title = "$r = -7cos(\\theta)$"
equation = lambda theta: -7 * np.cos(theta)
limits = (0, 8)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = -7.0
# Vertex 2: θ = π, r = 7.0

# %%
# r = -10 * sin(θ)
title = "$r = -10sin(\\theta)$"
equation = lambda theta: -10 * np.sin(theta)
limits = (0, 11)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = -10.0
# Vertex 2: θ = 3π/2, r = 10.0

# %%
# r = -1
title = "$r = -1$"
equation = lambda theta: -1
limits = (-2, 0)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 0 vertices:

# %%
# r = 8 * sin(θ)
title = "$r = 8sin(\\theta)$"
equation = lambda theta: 8 * np.sin(theta)
limits = (0, 9)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = 8.0
# Vertex 2: θ = 3π/2, r = -8.0

# %%
# r= 5 * cos(θ)
title = "$r = 5cos(\\theta)$"
equation = lambda theta: 5 * np.cos(theta)
limits = (0, 6)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = 5.0
# Vertex 2: θ = π, r = -5.0

# %%
# r = -3 * cos(θ)
title = "$r = -3cos(\\theta)$"
equation = lambda theta: -3 * np.cos(theta)
limits = (0, 4)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = -3.0
# Vertex 2: θ = π, r = 3.0

# %%
# r = -sin(θ)
title = "$r = -sin(\\theta)$"
equation = lambda theta: -np.sin(theta)
limits = (0, 1.2)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = -1.0
# Vertex 2: θ = 3π/2, r = 1.0

# %%
# r^2 = 4 * sin^2(θ)
title = "$r^2 = 4sin^2(\\theta)$"
equation = lambda theta: np.sqrt(4 * np.sin(theta)**2)
limits = (0, 2.5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 4 vertices:
# Vertex 1: θ = 0, r = 0.01
# Vertex 2: θ = π/2, r = 2.0
# Vertex 3: θ = π, r = 0.01
# Vertex 4: θ = 3π/2, r = 2.0

# %% [markdown]
# ## Graphing Roses

# %%
# r = 2 * sin(5θ)
title = "$r = 2sin(5\\theta)$"
equation = lambda theta: 2 * np.sin(5 * theta)
limits = (0, 2.5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 10 vertices:
# Vertex 1: θ = 0.10π, r = 2.0
# Vertex 2: θ = 0.30π, r = -2.0
# Vertex 3: θ = π/2, r = 2.0
# Vertex 4: θ = 0.70π, r = -2.0
# Vertex 5: θ = 0.90π, r = 2.0
# Vertex 6: θ = 1.10π, r = -2.0
# Vertex 7: θ = 1.30π, r = 2.0
# Vertex 8: θ = 3π/2, r = -2.0
# Vertex 9: θ = 1.70π, r = 2.0
# Vertex 10: θ = 1.90π, r = -2.0

# %%
# r = -4 * cos(3θ)
title = "$r = -4cos(3\\theta)$"
equation = lambda theta: -4 * np.cos(3 * theta)
limits = (0, 5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 6 vertices:
# Vertex 1: θ = 0, r = -4.0
# Vertex 2: θ = π/3, r = 4.0
# Vertex 3: θ = 2π/3, r = -4.0
# Vertex 4: θ = π, r = 4.0
# Vertex 5: θ = 4π/3, r = -4.0
# Vertex 6: θ = 5π/3, r = 4.0

# %%
# r = -3 * sin(2θ)
title = "$r = -3sin(2\\theta)$"
equation = lambda theta: -3 * np.sin(2 * theta)
limits = (0, 3.5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits, handle_negative_r=True)
# Out:
# Found 4 vertices:
# Vertex 1: θ = π/4, r = -3.0
# Vertex 2: θ = 3π/4, r = 3.0
# Vertex 3: θ = 5π/4, r = -3.0
# Vertex 4: θ = 7π/4, r = 3.0
#   (Also marks: θ = 5π/4, r = 3.0) as negative equivalent
#   (Also marks: θ = π/4, r = 3.0) as negative equivalent

# %%
# r = 7 * cos(4θ)
title = "$r = 7cos(4\\theta)$"
equation = lambda theta: 7 * np.cos(4 * theta)
limits = (0, 8)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits, handle_negative_r=True)
# Out:
# Found 8 vertices:
# Vertex 1: θ = 0, r = 7.0
# Vertex 2: θ = π/4, r = -7.0
# Vertex 3: θ = π/2, r = 7.0
# Vertex 4: θ = 3π/4, r = -7.0
# Vertex 5: θ = π, r = 7.0
# Vertex 6: θ = 5π/4, r = -7.0
# Vertex 7: θ = 3π/2, r = 7.0
# Vertex 8: θ = 7π/4, r = -7.0
#   (Also marks: θ = 5π/4, r = 7.0) as negative equivalent
#   (Also marks: θ = 7π/4, r = 7.0) as negative equivalent
#   (Also marks: θ = π/4, r = 7.0) as negative equivalent
#   (Also marks: θ = 3π/4, r = 7.0) as negative equivalent

# %%
# r = 5 * cos(12θ)
title = "$r = 5cos(12\\theta)$"
equation = lambda theta: 5 * np.cos(12 * theta)
limits = (0, 6)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits, n_points=5000, handle_negative_r=True)
# Out:
# Found 24 vertices:
# Vertex 1: θ = 0, r = 5.0
# Vertex 2: θ = 0.08π, r = -5.0
# Vertex 3: θ = π/6, r = 5.0
# Vertex 4: θ = π/4, r = -5.0
# Vertex 5: θ = π/3, r = 5.0
# Vertex 6: θ = 0.42π, r = -5.0
# Vertex 7: θ = π/2, r = 5.0
# Vertex 8: θ = 0.58π, r = -5.0
# Vertex 9: θ = 2π/3, r = 5.0
# Vertex 10: θ = 3π/4, r = -5.0
# Vertex 11: θ = 5π/6, r = 5.0
# Vertex 12: θ = 0.92π, r = -5.0
# Vertex 13: θ = π, r = 5.0
# Vertex 14: θ = 1.08π, r = -5.0
# Vertex 15: θ = 7π/6, r = 5.0
# Vertex 16: θ = 5π/4, r = -5.0
# Vertex 17: θ = 4π/3, r = 5.0
# Vertex 18: θ = 1.42π, r = -5.0
# Vertex 19: θ = 3π/2, r = 5.0
# Vertex 20: θ = 1.58π, r = -5.0
# Vertex 21: θ = 5π/3, r = 5.0
# Vertex 22: θ = 7π/4, r = -5.0
# Vertex 23: θ = 11π/6, r = 5.0
# Vertex 24: θ = 1.92π, r = -5.0
#   (Also marks: θ = 1.08π, r = 5.0) as negative equivalent
#   (Also marks: θ = 5π/4, r = 5.0) as negative equivalent
#   (Also marks: θ = 1.42π, r = 5.0) as negative equivalent
#   (Also marks: θ = 1.58π, r = 5.0) as negative equivalent
#   (Also marks: θ = 7π/4, r = 5.0) as negative equivalent
#   (Also marks: θ = 1.92π, r = 5.0) as negative equivalent
#   (Also marks: θ = 0.08π, r = 5.0) as negative equivalent
#   (Also marks: θ = π/4, r = 5.0) as negative equivalent
#   (Also marks: θ = 0.42π, r = 5.0) as negative equivalent
#   (Also marks: θ = 0.58π, r = 5.0) as negative equivalent
#   (Also marks: θ = 3π/4, r = 5.0) as negative equivalent
#   (Also marks: θ = 0.92π, r = 5.0) as negative equivalent

# %%
c = 6 / math.sin(27*math.pi / 2)
print(f"c = {c}")

# r = -6 * sin(9θ)
title = "$r = -6sin(9\\theta)$"
equation = lambda theta: -6 * np.sin(9 * theta)
limits = (0, 7)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits, n_points=3000, handle_negative_r=True)
# Out:
# c = -6.0
# Found 18 vertices:
# Vertex 1: θ = 0.06π, r = -6.0
# Vertex 2: θ = π/6, r = 6.0
# Vertex 3: θ = 0.28π, r = -6.0
# Vertex 4: θ = 0.39π, r = 6.0
# Vertex 5: θ = π/2, r = -6.0
# Vertex 6: θ = 0.61π, r = 6.0
# Vertex 7: θ = 0.72π, r = -6.0
# Vertex 8: θ = 5π/6, r = 6.0
# Vertex 9: θ = 0.94π, r = -6.0
# Vertex 10: θ = 1.06π, r = 6.0
# Vertex 11: θ = 7π/6, r = -6.0
# Vertex 12: θ = 1.28π, r = 6.0
# Vertex 13: θ = 1.39π, r = -6.0
# Vertex 14: θ = 3π/2, r = 6.0
# Vertex 15: θ = 1.61π, r = -6.0
# Vertex 16: θ = 1.72π, r = 6.0
# Vertex 17: θ = 11π/6, r = -6.0
# Vertex 18: θ = 1.94π, r = 6.0
#   (Also marks: θ = 1.06π, r = 6.0) as negative equivalent
#   (Also marks: θ = 1.28π, r = 6.0) as negative equivalent
#   (Also marks: θ = 3π/2, r = 6.0) as negative equivalent
#   (Also marks: θ = 1.72π, r = 6.0) as negative equivalent
#   (Also marks: θ = 1.94π, r = 6.0) as negative equivalent
#   (Also marks: θ = π/6, r = 6.0) as negative equivalent
#   (Also marks: θ = 0.39π, r = 6.0) as negative equivalent
#   (Also marks: θ = 0.61π, r = 6.0) as negative equivalent
#   (Also marks: θ = 5π/6, r = 6.0) as negative equivalent

# %% [markdown]
# ## Graphing Cardioids

# %%
# r = 5 - 5 * cos(θ)
title = "$r = 5 - 5cos(\\theta)$"
equation = lambda theta: 5 - 5 * np.cos(theta)
limits = (0, 11)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = 0.0
# Vertex 2: θ = π, r = 10.0

# %%
# r = 3 - 3 * sin(θ)
title = "$r = 3 - 3sin(\\theta)$"
equation = lambda theta: 3 - 3 * np.sin(theta)
limits = (0, 7)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = 0.0
# Vertex 2: θ = 3π/2, r = 6.0

# %%
# r = -2 - 2 * sin(θ)
title = "$r = -2 - 2sin(\\theta)$"
equation = lambda theta: -2 - 2 * np.sin(theta)
limits = (-4, 1)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = -4.0
# Vertex 2: θ = 3π/2, r = -0.0

# %%
# r = -3 - 3 * cos(θ)
title = "$r = -3 - 3cos(\\theta)$"
equation = lambda theta: -3 - 3 * np.cos(theta)
limits = (-6, 1)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = -6.0
# Vertex 2: θ = π, r = -0.0

# %%
# r = 2 + 2 * cos(θ)
title = "$r = 2 + 2cos(\\theta)$"
equation = lambda theta: 2 + 2 * np.cos(theta)
limits = (0, 5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = 0, r = 4.0
# Vertex 2: θ = π, r = 0.0

# %%
# r = 1 + sin(θ)
title = "$r = 1 + sin(\\theta)$"
equation = lambda theta: 1 + np.sin(theta)
limits = (0, 2.5)

# Create the polar plot
plot_polar_equation(title, equation, limits=limits)
# Out:
# Found 2 vertices:
# Vertex 1: θ = π/2, r = 2.0
# Vertex 2: θ = 3π/2, r = 0.0
